# %% [markdown]
# <a href="https://colab.research.google.com/github/ldk7024/-/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #인공지능 사관학교 1주차 과제
# **목차**
# 1. 언어
# 2. 음성
# 3. 이미지
# 4. 자율주행
# 5. 출처
#
#
# ##언어
# 1. **구글번역**
#
#    2007년 구글에서 발표한 무료 번역 서비스
#
#   원래는 정확하지 않는 서비스로 사용자들에게 비난을 많이 받는 번역 프로그램이였지만 2016년 9월 28일부터 알파고에도 적용되는 딥러닝 기술을 적용하여 기존의 오류를 줄였고, 구글 신경 기계번역 시스템 (GNMT)을 이용하여 기존 PBMT 기반(문구기반 시스템)보다 오류가 평균 60%가 줄었다.
#
# 2. **파파고**
#
#    네이버가 2016년 8월 8일 애플리케이션으로 선보인 인공지능 기반 번역기
#
#    가장 뛰어난 한국어 번역 품질을 제공하는 인공 신경망기반 기계 번역 API
#    한국어, 일본어, 중국어, 영어, 스페인어, 프랑스어, 베트남어, 태국어, 인도네시아어, 독일어, 러시아어, 포르투갈어, 힌디어 13개의 언어를 번역할 수 있다. 텍스트나 음성 뿐 아니라 사진 속 문자까지 통·번역할 수 있다.
#
# 3. **심심이**
#
#      ㈜심심이(구, ㈜이즈메이커)에서 2002년 개발한 인공지능 대화 엔진. SMS   서비스로 웹2.0의 대표적인 사례이다.
#
#       최초에는 MSN 봇 형태였으나 2004년 KT와 제휴하여 모바일 서비스를        개시하였으나, 당해 7월 KT에서 '심심이'에 대한 상표를 등록하였으며 이즈메이커는 2008년부터 '심심이' 이름을 사용할 수 없게 되어 '틈틈이'라는 이름으로 새로운 서비스를 개발하다가 KT와의 상표권 소송에서 승소하여 '심심이' 상표를 다시 되찾아 현재에 이르고 있다. 이후, 회사명도 이즈메이커에서 심심이로 바뀌었다.
#
#   음성이 아닌 텍스트 기반이지만, Siri를 비롯한 '개인용 인공지능'의 프로토타입을 제시하고 있다.
#
#
# ###음성
#
# 1. **KT기가지니**
#
#   KT에서 2017년 1월 최초 출시된 셋톱박스 기능을 탑재한 인공지능 스피커 제품,
#   세계 최초로 IPTV와 인공지능의 융합으로 TV와 연계한 홈 비서 기능을 제공한다
#
# 2. **빅스비**
#
#   삼성전자가 비브 개발진과 협력 해 개발 한 딥러닝 기반의 발전된 소프트웨어 인공지능 서비스이며, 갤럭시 스마트폰 뿐만 아니라 삼성의 모든 스마트 기기에 탑재할 것이라고 한다.
#
#   빅스비는 이용 데이터가 쌓일수록 더 정교해지는 딥러닝 기술을 바탕으로 개발되서 점점 더 빅스비는 시간이 지날수록 더욱 발전될 것으로 보인다.
#
#
# ###이미지
#
#   1. **구글 포토 서비스**
#
#   2015년 5월 29일에 구글 I/O 2015에서 발표한 사진 관리 서비스
#
#   수십 만장의 사진으로 머신러닝을 훈련해서 어느 방향으로도 똑바로 볼 수 있는 머신러닝 알고리즘을 개발해 적용했다.
#
#   머신러닝 기술을 적용해 스캔한 사진의 가장자리를 감지하고, 이미지를 올바른    방향으로 회전시키는 등 별도의 스캔 장비 없이도 손쉽게 아날로그 사진을 디지털 사진으로 변환시킬 수 있다.
#
#   2. **WATSON**
#
#      뉴욕의 Memorial Sloan Kettering Cancer Center에서는 AI인 Watson을 도입하여 신속하고 정확한 암진단에 도움을 받고 있다.
#
#      Memorial Sloan Kettering Cancer Center는 선도적으로 AI를 도입해 유명해진 병원이다. Watson 도입 당시 IBM과 연계하여 200만 페이지, 25만 건의 암 사례를 학습시켰다. 학습에 14,700만 시간이라는 방대한 시간을 쓴 결과, Watson은 10분 만에 희귀 백혈병을 진단해냈다고 한다.
#
# ####자율주행
#
# 1. SCC-ML
#
#   현대자동차와 기아자동차는 운전자의 주행성향에 맞는 부분 자율주행을 구현하는 기술
#
#  현대차·기아차가 독자 개발한 SCC-ML의 원리는 먼저 전방카메라, 레이더 등의 센서가 다양한 운전상황에서 발생되는 정보를 지속적으로 수집해 ADAS의 두뇌격인 제어컴퓨터로 보낸다.
#
#  제어컴퓨터는 입력된 정보로부터 운전자의 주행습관을 추출해 종합적인 주행성향을 파악한다. 이때 인공지능 기술 중 하나인 머신러닝 알고리즘이 적용된다.
#
# 2. **테슬라 오토파일럿**
#
#  테슬라 자동차에서 사용되고 있는 ADAS 시스템으로서 운전자없이 자동차를 운행하는 것을 최종 목표로 하고 있다.
#
#  가장 앞선 자율주행기술을 가지고 있는 것으로 알려진 테슬라는 100만대 이상의 자동차중 HW2이상의 하드웨어를 가진 80만대의 테슬라 자동차를 통해서 하루에도 웨이모의 데이터이상의 실도로 데이터를 수집할 수 있는 역량을 갖추고 있다. 같은 시기 테슬라는 30억마일(48억km)의 실도로 주행 데이터를 가지고 있다.
#
# #####출처
#
# 1. [나무위키] (https://namu.wiki/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8)
#
# 2. [인공지능신문]
# (http://www.aitimes.kr/)
#
# 3. [AP MAGAGINE] (http://www.withpress.co.kr/)
